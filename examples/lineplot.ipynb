# %%
from nnterp_kit.viz import display_line_plot


data = {
    "lines": [
        [0.1, 0.2],
        [0.2, 0.4],
        [0.3, 0.6],
    ],
    "ranks": [
        [1, 2],
        [2, 1],
        [3, 5],
    ],
    "prob_diffs": [
        [0.1, 0.2],
        [0.2, 0.4],
        [0.3, 0.6],
    ],
    "tokenLabels": [
        "a",
        "b",
        "c"
    ]
}
fig = display_line_plot(data)

# %%
from nnterp_kit.viz import display_logit_lens

data = {
    "logits": [
        [0.1, 0.2],
        [0.2, 0.4],
        [0.3, 0.6],
    ],
}

display_logit_lens(data)
